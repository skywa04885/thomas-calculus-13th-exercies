# %% [markdown]
# 31. $f(x) = 3 - 2x,\ c = 3,\ \epsilon = \frac{2}{100}$
#
#     $L = \lim_{x \to 3} (3 - 2x) = 3 - 6 = -3$
#
#     $0 < |x - 3|$
#
#     $= |(3 - 2x) + 3|$
#
#     $= |6 - 2x|$
#
#     $= 2|3 - x| = -2|x - 3|$
#
#     $= -2|x - 3| \lt -2 \delta$
#
#     $\epsilon = -2 \delta$
#
#     $-\frac{\epsilon}{2} = \delta$
#
#     Then just to evaluate
#
#     $\left. \delta \right|_{\epsilon = 2/100} = -\frac{2}{100} \div \frac{2}{1} = -\frac{2}{100} \cdot \frac{1}{2} = -\frac{2}{200} = -\frac{1}{100} = -0.01$

# %% [markdown]
# 33. $f(x) = \frac{x^2 - 4}{x - 2}, c = 2, \epsilon = 0.05$
#
#     $L = \lim_{x \to 2} \frac{x^2 - 4}{x - 2} = \lim_{x \to 2} \frac{(x - 2)(x + 2)}{(x - 2)} = \lim_{x \to 2} x + 2,\ x \neq 2 = 4$
#
#     $0 \lt |x - 2| \lt \delta$
#
#     $|\frac{x^2 - 4}{x - 2} - 4| \lt \epsilon$
#
#     $|\frac{(x + 2)(x - 2)}{(x - 2)} - 4| \lt \epsilon$
#
#     $|\frac{x + 2}{1} - 4| \lt \epsilon$
#
#     $|x + 2 - 4| \lt \epsilon$
#
#     $|x - 2| \lt \epsilon = \delta$

# %% [markdown]
# 35. $f(x) = \sqrt{1 - 5x},\ c = -3,\ \epsilon = 0.5$
#
#     $L = \lim_{x \to -3} \sqrt{1 - 5x} = \sqrt{1 + 15} = \sqrt{16} = 4$
#
#     $0 \lt |x + 3| \lt \delta$
#
#     $|\sqrt{1 - 5x} - 4| \lt \epsilon$
#
#     $\big|\frac{(\sqrt{1 - 5x} - 4)(\sqrt{1 - 5x} + 4)}{(\sqrt{1 - 5x} + 4)}\big| \lt \epsilon$
#
#     $\big|\frac{1 -5x - 16}{\sqrt{1 - 5x} + 4}\big| \lt \epsilon$
#
#     $\big|\frac{-5x -15}{\sqrt{1 - 5x} + 4}\big| \lt \epsilon$
#
#     $\big|\frac{-5(x + 3)}{\sqrt{1 - 5x} + 4}\big| \lt \epsilon$
#
#     $5\big|\frac{x + 3}{\sqrt{1 - 5x} + 4}\big| \lt \epsilon$
#
#     We'll never reach negative numbers (it will be undefined) so we can do this.
#
#     $\frac{5|x + 3|}{\sqrt{1 - 5x} + 4} \leq \frac{5|x + 3|}{4} = \frac{5}{4} |x + 3| \lt \frac{5}{4} \delta$
#
#     $\frac{5|x + 3|}{\sqrt{1 - 5x} + 4} \leq \frac{5}{4} |x + 3| \lt \frac{5}{4} \delta$
#
#     $\frac{5}{4} \delta = \frac{5 \delta}{4} = \epsilon$
#
#     $5 \delta = 4 \epsilon$
#
#     $\delta = \frac{4}{5} \epsilon$

# %% [markdown]
# 36. ((ERROR)) $f(x) = \frac{4}{x},\ c = 2,\ \epsilon=0.4$
#
#     $L = \lim_{x \to 2} \frac{4}{x} = \frac{4}{2} = 2$
#
#     $\delta = \min{1,\ -\frac{\epsilon}{2}}$
#
#     We're going to connect the following inequalities together:
#
#     $0 \lt |x - 2| \lt \delta$
#
#     $|\frac{4}{x} - 2| \lt \epsilon$
#
#     Let's do it!
#
#     $(\ |x\{4-2x\}| = |2x\{2-x\}| = |-2x\{x - 2\}|\ ) \lt \epsilon$
#
#     However! Because we take the absolute value, $-2$ or $2$ doesn't matter. We can remove it.
#
#     $|2x| \cdot |x - 2| \lt z \cdot \delta$
#
#     Now let's solve for the z:
#
#     $|x - 2| \lt 1$
#
#     $|2x - 4| \lt 2$
#
#     $|2x - 4| \leq |2x| + 4 \lt 2$
#
#     Now we end up with the following inequality
#
#     $|2x| \cdot |x - 2| \lt -2 \delta$
#
#     Now to solve for delta
#
#     $-2\delta = \epsilon$
#
#     $\delta = -\frac{\epsilon}{2}$

# %% [markdown]
# 36. ((ERROR)) $f(x) = \frac{4}{x},\ c = 2,\ \epsilon = 0.4$
#
#     $L = \lim_{x \to 2} \frac{4}{x} = \frac{4}{2} = 2$
#
#     _Given:_
#
#     $\epsilon \gt 0$
#
#     Choose $\delta = \min{\{1, \}}$
#
#     _Suppose:_
#
#     $0 \lt |x - 2| \lt \delta$
#
#     _Check:_
#
#     $|\frac{4}{x} - 2|$
#
#     $= |x(4 - 2x)| = |2x(2 - x)| = |-2x(x - 2)|$
#
#     $= |2x(x - 2)|$
#
#     $= |2x| \cdot |x - 2|$
#
#     $ < \cdot \delta$
#
#     ---
#
#     $|x - 2| \lt 1$
#
#     $|2x - 4| \lt 2$
#
#     $|2x - 4| \leq |2x| + |4|$

# %% [markdown]
# 36. $f(x) = \frac{4}{x},\ c = 2,\ \epsilon = 0.4$
#
#     $L = \lim_{x \to 2} \frac{4}{x} = \frac{4}{2} = 2$
#
#     Let's find the interval.
#
#     $|\frac{4}{x} - 2| \lt 0.4$
#
#     $-0.4 \lt \frac{4}{x} - 2 \lt 0.4$
#
#     $1.6 \lt \frac{4}{x} \lt 2.4$
#
#     $\frac{1.6}{4} \lt \frac{1}{x} \lt \frac{2.4}{4}$
#
#     $\frac{4}{1.6} \lt x \lt \frac{4}{2.4}$
#
#     $\frac{5}{2} \lt x \lt \frac{5}{3}$
#
#     $\frac{4}{1} \cdot \frac{10}{24} = \frac{40}{24} = \frac{20}{12} = \frac{10}{6} = \frac{5}{3}$
#
#     $\frac{4}{1} \cdot \frac{10}{16} = \frac{40}{16} = \frac{20}{8} = \frac{10}{4} = \frac{5}{2}$

# %% [markdown]
# 43. $\lim_{x \to 1} \frac{1}{x} = 1$
#
#     First we've been given these inequalities.
#
#     $0 \lt |x - 1| \lt \delta$ and $|\frac{1}{x} - 1| \lt \epsilon$
#
#     $1 \gt \epsilon \gt 0$
#
#     Let's get started.
#
#     $|\frac{1}{x} - 1| \lt \epsilon$
#
#     $-\epsilon \lt \frac{1}{x} - 1 \lt \epsilon$
#
#     $1 - \epsilon \lt \frac{1}{x} \lt \epsilon + 1$
#
#     $\frac{1}{1 - \epsilon} \lt x \lt \frac{1}{\epsilon + 1}$
#
#     $\delta = \min{\{ \frac{1}{1 - \epsilon}, \frac{1}{1 + \epsilon} \}} = \frac{1}{1 + \epsilon}$
#
#     Which proves the limit because.
#
#     $|x - 1| \lt \delta$
#
#     $- \delta \lt x + 1 \lt \delta$
#
#     $-\frac{1}{1 + \epsilon} \lt x + 1 \lt \frac{1}{1 + \epsilon}$
#
#     $\frac{1}{\epsilon - 1} \lt x + 1 \lt \frac{1}{1 + \epsilon}$
#
#     $\frac{1}{\epsilon - 1} - 1 \lt x \lt \frac{1}{1 + \epsilon} - 1$

# %% [markdown]
# 45. $\lim_{x \to -3} \frac{x^2 - 9}{x + 3} = -6$
#
#     $|\frac{x^2 - 9}{x + 3} + 6| \lt \epsilon$
#
#     $- \epsilon \lt \frac{x^2 - 9}{x + 3} + 6 \lt \epsilon$
#
#     $- \epsilon - 6 \lt \frac{x^2 - 9}{x + 3} \lt \epsilon - 6$
#
#     $- (\epsilon + 6)(x + 3) \lt x^2 - 9 \lt (\epsilon - 6)(x + 3)$
#
#     $- (\epsilon + 6)(x + 3) \lt (x - 3)(x + 3) \lt (\epsilon - 6)(x + 3)$
